# %%
import random
import os
import re
import time
from matplotlib import pyplot as plt

# %%
import numpy as np
import tensorflow as tf
from pathlib import Path
from collections import namedtuple
from tqdm import tqdm
from yargy.tokenizer import *
import string

# %%
FactRu = namedtuple('FactRu', ['id', 'text'])

# %%
devset_dir = "factRuEval-2016/devset"
testset_dir = "factRuEval-2016/testset"
result_dir = "factRuEval-2016/results"

# %%
def load_data(path):
    with open(path) as file:
        return file.read()

# %%
def read_dataset(dir_path, filetype):
    for filename in os.listdir(dir_path):
        match = re.match('book_(\d+)\.'+filetype, filename)
        if match:
            id = int(match.group(1))
            path = os.path.join(dir_path, filename)
            text = load_data(path)
            yield FactRu(id, text)

# %%
train_tokens = list(read_dataset(devset_dir, 'tokens'))
test_tokens = list(read_dataset(testset_dir, 'tokens'))
train_objects = list(read_dataset(devset_dir, 'objects'))
test_objects = list(read_dataset(testset_dir, 'objects'))

# %%
train_text = list(read_dataset(devset_dir, 'txt'))
test_text = list(read_dataset(testset_dir, 'txt'))

# %%
print(train_text[0].text)
# Out:
# Второй год подряд увеличивается число арестованных за их работу журналистов, причём каждый третий заключенный журналист — работал в Интернете. Об этом сообщает Комитет защиты журналистов (КЗЖ) (Committee to Protect Journalists).
#
# На 1 декабря 2006 года во всём мире — 134 журналиста находятся в тюрьмах, это на 9 больше, чем в 2005 году. Журналисты арестованы в 24-х странах. Наибольшее количество арестованных журналистов в Китае, Кубе, Эритрее и в Эфиопии.
#
# Наибольшее количество арестованных журналистов (67) — это репортёры, редакторы и фотографы. Однако в последнее время растёт количество журналистов, которые подвергаются арестам за их работу в Интернете (в этом году — 49). С 1997 года, когда был арестован первый журналист-интернетчик, количество их растёт наибольшими темпами.
#
# Список заключенных интернет-журналистов включает репортёров из Китая, независимых авторов из Кубы, которые пишут для зарубежных Интернет страниц и американского видео-блоггера Джошуа Вольфа (Joshua Wolf), который отказался передать материалы большому жюри.
#
# «Мы находимся на критическом этапе борьбы за свободу прессы, потому что авторитарные государства прилагают большие усилия, чтобы управлять информацией в Интернете», сказал руководитель КЗЖ Джоэл Саймон (Joel Simon). «Китай пытается противостоять тому, что Интернет неуправляем и не подвержен цензуре, и если это им удастся, то это будет иметь далеко идущие последствия не только для Интернета, но и для свободы печати во всем мире».
#
# Наиболее распространенные обвинения, которые используются, чтобы отправлять журналистов за решетку во всем мире — это «антигосударственные» заявления, подрывная деятельность, разглашение государственных тайн, и действия против интересов государства. По таким обвинениям заключены в тюрьмы 84 журналиста в Китае, в Кубе и в Эфиопии.
#
# В докладе отмечается увеличение количества арестов журналистов вообще без всяких обвинений. В Эритрее журналисты арестовываются без обвинений, они содержатся в секретных местах, никакие сведения о них не сообщаются. В США содержатся в заключении без обвинений два журналиста: фотограф Ассошиэйтед Пресс Билал Хассеин (Bilal Hussein), и оператор Аль-Джазиры Сами аль-Хадж (Sami al-Haj), которые находится в тюрьме уже пять лет и в настоящий момент содержится в Гуантанамо (Куба).
#
# Последние восемь лет наибольшее количество журналистов содержится в тюрьмах Китая. В этом году их — 31. Три четверти из них были обвинены по расплывчатым формулировкам «антигосударственной деятельности». 19 журналистов, арестованных в Китае — это журналисты, работающие в Интернете. Продолжает отбывать 10-и летний срок заключения известный журналист Ши Тао (Shi Tao), которые опубликовал в Интернете инструкции отдела пропаганды по поводу очередной годовщины событий на площади Тяньаньмынь. Правительство Китая объявило эти инструкции «государственной тайной».
#
# Куба содержит 24 журналиста за решёткой, это второе, после Китая, место.
#
# Эритрея — лидер среди африканских стран, с 23 журналистами в тюрьме. Эти заключенные считаются отрезанными от внешнего мира, и их состояние вызывает беспокойство. Возможно, некоторые из низ уже мертвы. Правительство Эритреи отказывается сообщать что-либо о местонахождении этих журналистов, их здоровье, и живы ли они всё еще. В соседней Эфиопии 18 заключенных журналистов, большинство которых были осуждены за измену. Далее следует Бирма с семью заключёнными журналистами. На шестом месте — Узбекистан, который держит пять журналистов в заключении. Соединенные Штаты, Азербайджан, и Бурунди являются седьмыми в списке наций — по три заключённых журналистов.
#
# Заключенные журналисты в России Комитет защиты журналистов считает, что в России два журналиста находятся в заключении из-за своей профессиональной деятельности.
#
# Борис Стомахин, редактор ежемесячной газеты «Радикальная политика», был арестован 22 марта 2006 года после подстрекательства к этнической ненависти и обнародования призывов к экстремистской деятельности.
#
# Владимир Королёв, фотограф независимого еженедельника «Пермский обозреватель», был арестован 11 сентября 2006 года и обвинён в раскрытии неуказанных государственных тайн по Статье 283 уголовного кодекса России.

# %%
def tokenize(texts):
    result = []
    tokenizer = MorphTokenizer()
    for text in texts:
        for line in text.text.splitlines():
            result.append(FactRu(text.id, [_.value for _ in tokenizer(line)]))
    return result

# %%
tokenized_train_text = tokenize(train_text)
tokenized_test_text = tokenize(test_text)

# %%
print(tokenized_train_text[0].text, tokenized_train_text[0].id)
# Out:
# ['Второй', 'год', 'подряд', 'увеличивается', 'число', 'арестованных', 'за', 'их', 'работу', 'журналистов', ',', 'причём', 'каждый', 'третий', 'заключенный', 'журналист', '—', 'работал', 'в', 'Интернете', '.', 'Об', 'этом', 'сообщает', 'Комитет', 'защиты', 'журналистов', '(', 'КЗЖ', ')', '(', 'Committee', 'to', 'Protect', 'Journalists', ')', '.'] 151

# %%
objects = tokenize(train_objects)
print(objects[0].text, objects[0].id)
# Out:
# ['17530', 'LocOrg', '33882', '#', 'США'] 282

# %%
def make_labels(objects):
    result = []
    tokenized_objects = tokenize(objects)
    for _ in tokenized_objects:
        if _.text[1] == 'Person':
            index = _.text.index('#')
            result.append(FactRu(_.id, ['PER', _.text[index+1:]]))
    return result

# %%
#only for person
train_labels = make_labels(train_objects)
test_labels = make_labels(test_objects)
print(train_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7d1d464c18e> in <module>()
#       1 #only for person
# ----> 2 train_labels = make_labels(train_objects)
#       3 test_labels = make_labels(test_objects)
#       4 print(train_labels)
#
# NameError: name 'make_labels' is not defined

# %%
def text_merge(lstlst):
    result = ''
    for lst in lstlst:
        result += lst.text
    return result

# %%
merged_train_text = text_merge(train_text)
print(merged_train_text)
# Out:
# Второй год подряд увеличивается число арестованных за их работу журналистов, причём каждый третий заключенный журналист — работал в Интернете. Об этом сообщает Комитет защиты журналистов (КЗЖ) (Committee to Protect Journalists).
# Значительно отличаются друг от друга официальные доклады НАСА и Роскосмоса о полётах кораблей, начиная с «Союз ТМ-2» и до корабля «Союз ТМ-15». Русские отчёты зачастую формальны, в то время как во время полёта возникает множество различных ситуаций, в которые вовлечены и экипаж и наземные службы, зачастую возникают ситуации, угрожающие жизни космонавтов.
#
# Говорят, что приземление корабля «Союз ТМА-11», это только третий баллистический спуск за всю историю полётов к МКС. Однако, эти три баллистических спуска произошли с новой модификацией корабля «Союз» — ТМА. Эти корабли летают с 2002 года. Перед этим был также спуск корабля ТМ с очень большими перегрузками. На этом корабле возвращался на Землю первый турист Денис Тито. Тогда всё списали на ошибки экипажа.

# %%
# import tensorflow as tf
# import numpy as np
# import string

# corpus_raw = merged_train_text

# # convert to lower case
# corpus_raw = corpus_raw.lower()
# punct = string.punctuation

# corpus_raw = re.sub('([.,!?()])', r' \1 ', corpus_raw)
# corpus_raw = re.sub('\s{2,}', ' ', corpus_raw)

# words = []
# for word in corpus_raw.split():
#     if word != punct: # because we don't want to treat . as a word
#         words.append(word)


# words = set(words) # so that all duplicate words are removed
# word2int = {}
# int2word = {}
# vocab_size = len(words) # gives the total number of unique words
# words = list(words)

# for i,word in enumerate(words):
#     word2int[word] = i
#     int2word[i] = word

# # raw sentences is a list of sentences.
# raw_sentences = corpus_raw.split('.?!')
# sentences = []
# for sentence in raw_sentences:
#     sentences.append(sentence.split())

# WINDOW_SIZE = 2

# data = []
# for sentence in sentences:
#     for word_index, word in enumerate(sentence):
#         for nb_word in sentence[max(word_index - WINDOW_SIZE, 0) : min(word_index + WINDOW_SIZE, len(sentence)) + 1] : 
#             if nb_word != word:
#                 data.append([word, nb_word])

# # function to convert numbers to one hot vectors
# def to_one_hot(data_point_index, vocab_size):
#     temp = np.zeros(vocab_size)
#     temp[data_point_index] = 1
#     return temp

# x_train = [] # input word
# y_train = [] # output word

# for data_word in data:
#     x_train.append(to_one_hot(word2int[ data_word[0] ], vocab_size))
#     y_train.append(to_one_hot(word2int[ data_word[1] ], vocab_size))

# # convert them to numpy arrays
# x_train = np.asarray(x_train)
# y_train = np.asarray(y_train)

# # making placeholders for x_train and y_train
# x = tf.placeholder(tf.float32, shape=(None, vocab_size))
# y_label = tf.placeholder(tf.float32, shape=(None, vocab_size))

# EMBEDDING_DIM = 5 # you can choose your own number
# W1 = tf.Variable(tf.random_normal([vocab_size, EMBEDDING_DIM]))
# b1 = tf.Variable(tf.random_normal([EMBEDDING_DIM])) #bias
# hidden_representation = tf.add(tf.matmul(x,W1), b1)

# W2 = tf.Variable(tf.random_normal([EMBEDDING_DIM, vocab_size]))
# b2 = tf.Variable(tf.random_normal([vocab_size]))
# prediction = tf.nn.softmax(tf.add( tf.matmul(hidden_representation, W2), b2))


# sess = tf.Session()
# init = tf.global_variables_initializer()
# sess.run(init) #make sure you do this!

# # define the loss function:
# cross_entropy_loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.log(prediction), reduction_indices=[1]))

# # define the training step:
# train_step = tf.train.GradientDescentOptimizer(0.1).minimize(cross_entropy_loss)

# n_iters = 100
# # train for n_iter iterations

# for _ in range(n_iters):
#     sess.run(train_step, feed_dict={x: x_train, y_label: y_train})
#     print('loss is : ', sess.run(cross_entropy_loss, feed_dict={x: x_train, y_label: y_train}))

# vectors = sess.run(W1 + b1)

# def euclidean_dist(vec1, vec2):
#     return np.sqrt(np.sum((vec1-vec2)**2))

# def find_closest(word_index, vectors):
#     min_dist = 10000 # to act like positive infinity
#     min_index = -1
#     query_vector = vectors[word_index]
#     for index, vector in enumerate(vectors):
#         if euclidean_dist(vector, query_vector) < min_dist and not np.array_equal(vector, query_vector):
#             min_dist = euclidean_dist(vector, query_vector)
#             min_index = index
#     return min_index


# from sklearn.manifold import TSNE

# model = TSNE(n_components=2, random_state=0)
# np.set_printoptions(suppress=True)
# vectors = model.fit_transform(vectors) 

# from sklearn import preprocessing

# normalizer = preprocessing.Normalizer()
# vectors =  normalizer.fit_transform(vectors, 'l2')

# print(vectors)

# import matplotlib.pyplot as plt


# fig, ax = plt.subplots()
# print(words)
# for word in words:
#     print(word, vectors[word2int[word]][1])
#     ax.annotate(word, (vectors[word2int[word]][0],vectors[word2int[word]][1] ))
# plt.show()

# %%
from yargy.predicates import normalized
corpus_raw = merged_train_text

# convert to lower case
corpus_raw = corpus_raw.lower()
punct = string.punctuation

corpus_raw = re.sub('([.,!?()])', r' \1 ', corpus_raw)
corpus_raw = re.sub('\s{2,}', ' ', corpus_raw)

words = []
for word in corpus_raw.split():
    if word != punct: # because we don't want to treat . as a word
        words.append(word)


words = set(words) # so that all duplicate words are removed
vocab_size = len(words) # gives the total number of unique words

# %%
tokenizer = MorphTokenizer().remove_types('EOL')
list(tokenizer(merged_train_text))
# Out:
# [MorphToken('Второй',
#             [0, 6),
#             'RU',
#             [Form('два', Grams(ADJF,Anum,masc,nomn,sing)),
#              Form('два', Grams(ADJF,Anum,femn,gent,sing)),
#              Form('втора', Grams(NOUN,ablt,femn,inan,sing)),
#              Form('два', Grams(ADJF,Anum,accs,inan,masc,sing)),
#              Form('два', Grams(ADJF,Anum,datv,femn,sing)),
#              Form('два', Grams(ADJF,Anum,ablt,femn,sing)),
#              Form('два', Grams(ADJF,Anum,femn,loct,sing))]),
#  MorphToken('год',
#             [7, 10),
#             'RU',
#             [Form('год', Grams(NOUN,accs,inan,masc,sing)),
#              Form('год', Grams(NOUN,inan,masc,nomn,sing))]),
#  MorphToken('подряд',
#             [11, 17),
#             'RU',
#             [Form('подряд', Grams(ADVB)),
#              Form('подряд', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('подряд', Grams(NOUN,accs,inan,masc,sing))]),
#  MorphToken('увеличивается',
#             [18, 31),
#             'RU',
#             [Form('увеличиваться',
#                   Grams(3per,VERB,impf,indc,intr,pres,sing))]),
#  MorphToken('число',
#             [32, 37),
#             'RU',
#             [Form('число', Grams(NOUN,inan,neut,nomn,sing)),
#              Form('число', Grams(NOUN,accs,inan,neut,sing))]),
#  MorphToken('арестованных',
#             [38, 50),
#             'RU',
#             [Form('арестованный', Grams(NOUN,anim,gent,masc,plur)),
#              Form('арестованный', Grams(NOUN,accs,anim,masc,plur)),
#              Form('арестованный', Grams(NOUN,anim,loct,masc,plur)),
#              Form('арестовать', Grams(PRTF,gent,past,perf,plur,pssv,tran)),
#              Form('арестовать',
#                   Grams(PRTF,accs,anim,past,perf,plur,pssv,tran)),
#              Form('арестовать', Grams(PRTF,loct,past,perf,plur,pssv,tran))]),
#  MorphToken('за', [51, 53), 'RU', [Form('за', Grams(PREP))]),
#  MorphToken('их',
#             [54, 56),
#             'RU',
#             [Form('они', Grams(3per,Anph,NPRO,gent,plur)),
#              Form('они', Grams(3per,Anph,NPRO,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,nomn,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,masc,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,gent,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,loct,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,neut,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,plur))]),
#  MorphToken('работу',
#             [57, 63),
#             'RU',
#             [Form('работа', Grams(NOUN,accs,femn,inan,sing))]),
#  MorphToken('журналистов',
#             [64, 75),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  Token(',', [75, 76), 'PUNCT'),
#  MorphToken('причём', [77, 83), 'RU', [Form('причём', Grams(CONJ))]),
#  MorphToken('каждый',
#             [84, 90),
#             'RU',
#             [Form('каждый', Grams(ADJF,Apro,accs,inan,masc,sing)),
#              Form('каждый', Grams(ADJF,Apro,masc,nomn,sing))]),
#  MorphToken('третий',
#             [91, 97),
#             'RU',
#             [Form('три', Grams(ADJF,Anum,masc,nomn,sing)),
#              Form('три', Grams(ADJF,Anum,accs,inan,masc,sing))]),
#  MorphToken('заключенный',
#             [98, 109),
#             'RU',
#             [Form('заключённый', Grams(NOUN,anim,masc,nomn,sing)),
#              Form('заключить',
#                   Grams(Adjx,PRTF,masc,nomn,past,perf,pssv,sing,tran)),
#              Form('заключить',
#                   Grams(Adjx,PRTF,accs,inan,masc,past,perf,pssv,sing,tran))]),
#  MorphToken('журналист',
#             [110, 119),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,masc,nomn,sing))]),
#  Token('—', [120, 121), 'OTHER'),
#  MorphToken('работал',
#             [122, 129),
#             'RU',
#             [Form('работать', Grams(VERB,impf,indc,intr,masc,past,sing))]),
#  MorphToken('в',
#             [130, 131),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('Интернете',
#             [132, 141),
#             'RU',
#             [Form('интернет', Grams(NOUN,inan,loct,masc,sing))]),
#  Token('.', [141, 142), 'PUNCT'),
#  MorphToken('Об', [143, 145), 'RU', [Form('о', Grams(PREP,Vpre))]),
#  MorphToken('этом',
#             [146, 150),
#             'RU',
#             [Form('это', Grams(NPRO,loct,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,loct,masc,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,loct,neut,sing))]),
#  MorphToken('сообщает',
#             [151, 159),
#             'RU',
#             [Form('сообщать', Grams(3per,VERB,impf,indc,pres,sing,tran))]),
#  MorphToken('Комитет',
#             [160, 167),
#             'RU',
#             [Form('комитет', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('комитет', Grams(NOUN,accs,inan,masc,sing))]),
#  MorphToken('защиты',
#             [168, 174),
#             'RU',
#             [Form('защита', Grams(NOUN,femn,gent,inan,sing)),
#              Form('защита', Grams(NOUN,femn,inan,nomn,plur)),
#              Form('защита', Grams(NOUN,accs,femn,inan,plur))]),
#  MorphToken('журналистов',
#             [175, 186),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  Token('(', [187, 188), 'PUNCT'),
#  MorphToken('КЗЖ', [188, 191), 'RU', [Form('кзж', Grams(UNKN))]),
#  Token(')', [191, 192), 'PUNCT'),
#  Token('(', [193, 194), 'PUNCT'),
#  Token('Committee', [194, 203), 'LATIN'),
#  Token('to', [204, 206), 'LATIN'),
#  Token('Protect', [207, 214), 'LATIN'),
#  Token('Journalists', [215, 226), 'LATIN'),
#  Token(')', [226, 227), 'PUNCT'),
#  Token('.', [227, 228), 'PUNCT'),
#  MorphToken('На',
#             [230, 232),
#             'RU',
#             [Form('на', Grams(PREP)),
#              Form('на', Grams(PRCL)),
#              Form('на', Grams(INTJ))]),
#  Token('1', [233, 234), 'INT'),
#  MorphToken('декабря',
#             [235, 242),
#             'RU',
#             [Form('декабрь', Grams(NOUN,gent,inan,masc,sing))]),
#  Token('2006', [243, 247), 'INT'),
#  MorphToken('года',
#             [248, 252),
#             'RU',
#             [Form('год', Grams(NOUN,gent,inan,masc,sing)),
#              Form('год', Grams(Infr,NOUN,inan,masc,nomn,plur)),
#              Form('год', Grams(Infr,NOUN,accs,inan,masc,plur))]),
#  MorphToken('во', [253, 255), 'RU', [Form('в', Grams(PREP,Vpre))]),
#  MorphToken('всём',
#             [256, 260),
#             'RU',
#             [Form('весь', Grams(ADJF,Apro,loct,neut,sing)),
#              Form('весь', Grams(ADJF,Apro,loct,masc,sing))]),
#  MorphToken('мире',
#             [261, 265),
#             'RU',
#             [Form('мир', Grams(NOUN,inan,loct,masc,sing)),
#              Form('миро', Grams(NOUN,inan,loct,neut,sing))]),
#  Token('—', [266, 267), 'OTHER'),
#  Token('134', [268, 271), 'INT'),
#  MorphToken('журналиста',
#             [272, 282),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,sing)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,sing))]),
#  MorphToken('находятся',
#             [283, 292),
#             'RU',
#             [Form('находиться', Grams(3per,VERB,impf,indc,intr,plur,pres)),
#              Form('находиться', Grams(3per,VERB,futr,indc,intr,perf,plur))]),
#  MorphToken('в',
#             [293, 294),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('тюрьмах',
#             [295, 302),
#             'RU',
#             [Form('тюрьма', Grams(NOUN,femn,inan,loct,plur))]),
#  Token(',', [302, 303), 'PUNCT'),
#  MorphToken('это',
#             [304, 307),
#             'RU',
#             [Form('это', Grams(PRCL)),
#              Form('это', Grams(NPRO,neut,nomn,sing)),
#              Form('это', Grams(NPRO,accs,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,accs,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,neut,nomn,sing))]),
#  MorphToken('на',
#             [308, 310),
#             'RU',
#             [Form('на', Grams(PREP)),
#              Form('на', Grams(PRCL)),
#              Form('на', Grams(INTJ))]),
#  Token('9', [311, 312), 'INT'),
#  MorphToken('больше',
#             [313, 319),
#             'RU',
#             [Form('большой', Grams(COMP,Qual)), Form('больше', Grams(ADVB))]),
#  Token(',', [319, 320), 'PUNCT'),
#  MorphToken('чем',
#             [321, 324),
#             'RU',
#             [Form('чем', Grams(CONJ)),
#              Form('что', Grams(NPRO,ablt,neut,sing)),
#              Form('что', Grams(NPRO,loct,neut,sing))]),
#  MorphToken('в',
#             [325, 326),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  Token('2005', [327, 331), 'INT'),
#  MorphToken('году',
#             [332, 336),
#             'RU',
#             [Form('год', Grams(NOUN,inan,loc2,masc,sing)),
#              Form('год', Grams(NOUN,datv,inan,masc,sing)),
#              Form('год', Grams(NOUN,gen2,inan,masc,sing))]),
#  Token('.', [336, 337), 'PUNCT'),
#  MorphToken('Журналисты',
#             [338, 348),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,masc,nomn,plur))]),
#  MorphToken('арестованы',
#             [349, 359),
#             'RU',
#             [Form('арестовать', Grams(PRTS,past,perf,plur,pssv))]),
#  MorphToken('в',
#             [360, 361),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  Token('24', [362, 364), 'INT'),
#  Token('-', [364, 365), 'PUNCT'),
#  MorphToken('х', [365, 366), 'RU', [Form('х', Grams(UNKN))]),
#  MorphToken('странах',
#             [367, 374),
#             'RU',
#             [Form('страна', Grams(NOUN,femn,inan,loct,plur))]),
#  Token('.', [374, 375), 'PUNCT'),
#  MorphToken('Наибольшее',
#             [376, 386),
#             'RU',
#             [Form('наибольший', Grams(ADJF,Qual,Supr,neut,nomn,sing)),
#              Form('наибольший', Grams(ADJF,Qual,Supr,accs,neut,sing))]),
#  MorphToken('количество',
#             [387, 397),
#             'RU',
#             [Form('количество', Grams(NOUN,inan,neut,nomn,sing)),
#              Form('количество', Grams(NOUN,accs,inan,neut,sing))]),
#  MorphToken('арестованных',
#             [398, 410),
#             'RU',
#             [Form('арестованный', Grams(NOUN,anim,gent,masc,plur)),
#              Form('арестованный', Grams(NOUN,accs,anim,masc,plur)),
#              Form('арестованный', Grams(NOUN,anim,loct,masc,plur)),
#              Form('арестовать', Grams(PRTF,gent,past,perf,plur,pssv,tran)),
#              Form('арестовать',
#                   Grams(PRTF,accs,anim,past,perf,plur,pssv,tran)),
#              Form('арестовать', Grams(PRTF,loct,past,perf,plur,pssv,tran))]),
#  MorphToken('журналистов',
#             [411, 422),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  MorphToken('в',
#             [423, 424),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('Китае',
#             [425, 430),
#             'RU',
#             [Form('китай', Grams(Geox,NOUN,Sgtm,inan,loct,masc,sing))]),
#  Token(',', [430, 431), 'PUNCT'),
#  MorphToken('Кубе',
#             [432, 436),
#             'RU',
#             [Form('куб', Grams(NOUN,inan,loct,masc,sing)),
#              Form('куба', Grams(Geox,NOUN,Sgtm,datv,femn,inan,sing)),
#              Form('куба', Grams(Geox,NOUN,Sgtm,femn,inan,loct,sing))]),
#  Token(',', [436, 437), 'PUNCT'),
#  MorphToken('Эритрее',
#             [438, 445),
#             'RU',
#             [Form('эритрея', Grams(Geox,NOUN,Sgtm,femn,inan,loct,sing)),
#              Form('эритрея', Grams(Geox,NOUN,Sgtm,datv,femn,inan,sing))]),
#  MorphToken('и',
#             [446, 447),
#             'RU',
#             [Form('и', Grams(CONJ)),
#              Form('и', Grams(INTJ)),
#              Form('и', Grams(PRCL)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,plur))]),
#  MorphToken('в',
#             [448, 449),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('Эфиопии',
#             [450, 457),
#             'RU',
#             [Form('эфиопия', Grams(Geox,NOUN,Sgtm,femn,inan,loct,sing)),
#              Form('эфиопия', Grams(Geox,NOUN,Sgtm,femn,gent,inan,sing)),
#              Form('эфиопия', Grams(Geox,NOUN,Sgtm,datv,femn,inan,sing))]),
#  Token('.', [457, 458), 'PUNCT'),
#  MorphToken('Наибольшее',
#             [460, 470),
#             'RU',
#             [Form('наибольший', Grams(ADJF,Qual,Supr,neut,nomn,sing)),
#              Form('наибольший', Grams(ADJF,Qual,Supr,accs,neut,sing))]),
#  MorphToken('количество',
#             [471, 481),
#             'RU',
#             [Form('количество', Grams(NOUN,inan,neut,nomn,sing)),
#              Form('количество', Grams(NOUN,accs,inan,neut,sing))]),
#  MorphToken('арестованных',
#             [482, 494),
#             'RU',
#             [Form('арестованный', Grams(NOUN,anim,gent,masc,plur)),
#              Form('арестованный', Grams(NOUN,accs,anim,masc,plur)),
#              Form('арестованный', Grams(NOUN,anim,loct,masc,plur)),
#              Form('арестовать', Grams(PRTF,gent,past,perf,plur,pssv,tran)),
#              Form('арестовать',
#                   Grams(PRTF,accs,anim,past,perf,plur,pssv,tran)),
#              Form('арестовать', Grams(PRTF,loct,past,perf,plur,pssv,tran))]),
#  MorphToken('журналистов',
#             [495, 506),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  Token('(', [507, 508), 'PUNCT'),
#  Token('67', [508, 510), 'INT'),
#  Token(')', [510, 511), 'PUNCT'),
#  Token('—', [512, 513), 'OTHER'),
#  MorphToken('это',
#             [514, 517),
#             'RU',
#             [Form('это', Grams(PRCL)),
#              Form('это', Grams(NPRO,neut,nomn,sing)),
#              Form('это', Grams(NPRO,accs,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,accs,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,neut,nomn,sing))]),
#  MorphToken('репортёры',
#             [518, 527),
#             'RU',
#             [Form('репортёр', Grams(NOUN,anim,masc,nomn,plur))]),
#  Token(',', [527, 528), 'PUNCT'),
#  MorphToken('редакторы',
#             [529, 538),
#             'RU',
#             [Form('редактор', Grams(NOUN,anim,masc,nomn,plur))]),
#  MorphToken('и',
#             [539, 540),
#             'RU',
#             [Form('и', Grams(CONJ)),
#              Form('и', Grams(INTJ)),
#              Form('и', Grams(PRCL)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,plur))]),
#  MorphToken('фотографы',
#             [541, 550),
#             'RU',
#             [Form('фотограф', Grams(NOUN,anim,masc,nomn,plur))]),
#  Token('.', [550, 551), 'PUNCT'),
#  MorphToken('Однако',
#             [552, 558),
#             'RU',
#             [Form('однако', Grams(CONJ,Prnt)), Form('однако', Grams(INTJ))]),
#  MorphToken('в',
#             [559, 560),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('последнее',
#             [561, 570),
#             'RU',
#             [Form('последний', Grams(ADJF,neut,nomn,sing)),
#              Form('последний', Grams(ADJF,accs,neut,sing)),
#              Form('последний', Grams(COMP))]),
#  MorphToken('время',
#             [571, 576),
#             'RU',
#             [Form('время', Grams(NOUN,accs,inan,neut,sing)),
#              Form('время', Grams(NOUN,inan,neut,nomn,sing))]),
#  MorphToken('растёт',
#             [577, 583),
#             'RU',
#             [Form('расти', Grams(3per,VERB,impf,indc,intr,pres,sing))]),
#  MorphToken('количество',
#             [584, 594),
#             'RU',
#             [Form('количество', Grams(NOUN,inan,neut,nomn,sing)),
#              Form('количество', Grams(NOUN,accs,inan,neut,sing))]),
#  MorphToken('журналистов',
#             [595, 606),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  Token(',', [606, 607), 'PUNCT'),
#  MorphToken('которые',
#             [608, 615),
#             'RU',
#             [Form('который', Grams(ADJF,Anph,Apro,Subx,nomn,plur)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,accs,inan,plur))]),
#  MorphToken('подвергаются',
#             [616, 628),
#             'RU',
#             [Form('подвергаться', Grams(3per,VERB,impf,indc,intr,plur,pres))]),
#  MorphToken('арестам',
#             [629, 636),
#             'RU',
#             [Form('арест', Grams(NOUN,datv,inan,masc,plur))]),
#  MorphToken('за', [637, 639), 'RU', [Form('за', Grams(PREP))]),
#  MorphToken('их',
#             [640, 642),
#             'RU',
#             [Form('они', Grams(3per,Anph,NPRO,gent,plur)),
#              Form('они', Grams(3per,Anph,NPRO,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,nomn,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,masc,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,gent,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,loct,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,neut,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,plur))]),
#  MorphToken('работу',
#             [643, 649),
#             'RU',
#             [Form('работа', Grams(NOUN,accs,femn,inan,sing))]),
#  MorphToken('в',
#             [650, 651),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('Интернете',
#             [652, 661),
#             'RU',
#             [Form('интернет', Grams(NOUN,inan,loct,masc,sing))]),
#  Token('(', [662, 663), 'PUNCT'),
#  MorphToken('в',
#             [663, 664),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('этом',
#             [665, 669),
#             'RU',
#             [Form('это', Grams(NPRO,loct,neut,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,loct,masc,sing)),
#              Form('этот', Grams(ADJF,Anph,Apro,Subx,loct,neut,sing))]),
#  MorphToken('году',
#             [670, 674),
#             'RU',
#             [Form('год', Grams(NOUN,inan,loc2,masc,sing)),
#              Form('год', Grams(NOUN,datv,inan,masc,sing)),
#              Form('год', Grams(NOUN,gen2,inan,masc,sing))]),
#  Token('—', [675, 676), 'OTHER'),
#  Token('49', [677, 679), 'INT'),
#  Token(')', [679, 680), 'PUNCT'),
#  Token('.', [680, 681), 'PUNCT'),
#  MorphToken('С',
#             [682, 683),
#             'RU',
#             [Form('с', Grams(PREP)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,inan,nomn,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,gent,inan,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,datv,femn,inan,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,accs,femn,inan,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,ablt,femn,inan,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,inan,loct,sing)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,inan,nomn,plur)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,gent,inan,plur)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,datv,femn,inan,plur)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,accs,femn,inan,plur)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,ablt,femn,inan,plur)),
#              Form('секунда', Grams(Abbr,Fixd,NOUN,femn,inan,loct,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,inan,neut,nomn,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,gent,inan,neut,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,datv,inan,neut,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,accs,inan,neut,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,ablt,inan,neut,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,inan,loct,neut,sing)),
#              Form('село', Grams(Abbr,Fixd,NOUN,inan,neut,nomn,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,gent,inan,neut,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,datv,inan,neut,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,accs,inan,neut,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,ablt,inan,neut,plur)),
#              Form('село', Grams(Abbr,Fixd,NOUN,inan,loct,neut,plur)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,masc,nomn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,gent,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,datv,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,accs,anim,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,ablt,anim,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,loct,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,femn,nomn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,femn,gent,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,datv,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,accs,anim,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,ablt,anim,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Name,Sgtm,anim,femn,loct,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,masc,nomn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,gent,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,datv,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,accs,anim,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,ablt,anim,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,loct,masc,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,femn,nomn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,femn,gent,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,datv,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,accs,anim,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,ablt,anim,femn,sing)),
#              Form('с',
#                   Grams(Abbr,Fixd,Init,NOUN,Patr,Sgtm,anim,femn,loct,sing))]),
#  Token('1997', [684, 688), 'INT'),
#  MorphToken('года',
#             [689, 693),
#             'RU',
#             [Form('год', Grams(NOUN,gent,inan,masc,sing)),
#              Form('год', Grams(Infr,NOUN,inan,masc,nomn,plur)),
#              Form('год', Grams(Infr,NOUN,accs,inan,masc,plur))]),
#  Token(',', [693, 694), 'PUNCT'),
#  MorphToken('когда',
#             [695, 700),
#             'RU',
#             [Form('когда', Grams(CONJ)), Form('когда', Grams(ADVB,Ques))]),
#  MorphToken('был',
#             [701, 704),
#             'RU',
#             [Form('быть', Grams(VERB,impf,indc,intr,masc,past,sing))]),
#  MorphToken('арестован',
#             [705, 714),
#             'RU',
#             [Form('арестовать', Grams(PRTS,masc,past,perf,pssv,sing))]),
#  MorphToken('первый',
#             [715, 721),
#             'RU',
#             [Form('один', Grams(ADJF,Anum,masc,nomn,sing)),
#              Form('один', Grams(ADJF,Anum,accs,inan,masc,sing))]),
#  MorphToken('журналист',
#             [722, 731),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,masc,nomn,sing))]),
#  Token('-', [731, 732), 'PUNCT'),
#  MorphToken('интернетчик',
#             [732, 743),
#             'RU',
#             [Form('интернетчик', Grams(NOUN,anim,masc,nomn,sing))]),
#  Token(',', [743, 744), 'PUNCT'),
#  MorphToken('количество',
#             [745, 755),
#             'RU',
#             [Form('количество', Grams(NOUN,inan,neut,nomn,sing)),
#              Form('количество', Grams(NOUN,accs,inan,neut,sing))]),
#  MorphToken('их',
#             [756, 758),
#             'RU',
#             [Form('они', Grams(3per,Anph,NPRO,gent,plur)),
#              Form('они', Grams(3per,Anph,NPRO,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,nomn,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,masc,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,masc,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,gent,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,femn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,femn,loct,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,neut,nomn,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,neut,sing)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,gent,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,datv,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,accs,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,ablt,plur)),
#              Form('их', Grams(ADJF,Anph,Apro,Fixd,loct,plur))]),
#  MorphToken('растёт',
#             [759, 765),
#             'RU',
#             [Form('расти', Grams(3per,VERB,impf,indc,intr,pres,sing))]),
#  MorphToken('наибольшими',
#             [766, 777),
#             'RU',
#             [Form('наибольший', Grams(ADJF,Qual,Supr,ablt,plur))]),
#  MorphToken('темпами',
#             [778, 785),
#             'RU',
#             [Form('темп', Grams(NOUN,ablt,inan,masc,plur))]),
#  Token('.', [785, 786), 'PUNCT'),
#  MorphToken('Список',
#             [788, 794),
#             'RU',
#             [Form('список', Grams(NOUN,accs,inan,masc,sing)),
#              Form('список', Grams(NOUN,inan,masc,nomn,sing))]),
#  MorphToken('заключенных',
#             [795, 806),
#             'RU',
#             [Form('заключённый', Grams(NOUN,anim,gent,masc,plur)),
#              Form('заключённый', Grams(NOUN,accs,anim,masc,plur)),
#              Form('заключённый', Grams(NOUN,anim,loct,masc,plur)),
#              Form('заключить', Grams(Adjx,PRTF,gent,past,perf,plur,pssv,tran)),
#              Form('заключить',
#                   Grams(Adjx,PRTF,accs,anim,past,perf,plur,pssv,tran)),
#              Form('заключить',
#                   Grams(Adjx,PRTF,loct,past,perf,plur,pssv,tran))]),
#  MorphToken('интернет',
#             [807, 815),
#             'RU',
#             [Form('интернет', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('интернет', Grams(NOUN,accs,inan,masc,sing))]),
#  Token('-', [815, 816), 'PUNCT'),
#  MorphToken('журналистов',
#             [816, 827),
#             'RU',
#             [Form('журналист', Grams(NOUN,anim,gent,masc,plur)),
#              Form('журналист', Grams(NOUN,accs,anim,masc,plur))]),
#  MorphToken('включает',
#             [828, 836),
#             'RU',
#             [Form('включать', Grams(3per,VERB,impf,indc,pres,sing,tran))]),
#  MorphToken('репортёров',
#             [837, 847),
#             'RU',
#             [Form('репортёр', Grams(NOUN,anim,gent,masc,plur)),
#              Form('репортёр', Grams(NOUN,accs,anim,masc,plur))]),
#  MorphToken('из',
#             [848, 850),
#             'RU',
#             [Form('из', Grams(PREP)),
#              Form('иза', Grams(NOUN,Name,anim,femn,gent,plur)),
#              Form('иза', Grams(NOUN,Name,accs,anim,femn,plur))]),
#  MorphToken('Китая',
#             [851, 856),
#             'RU',
#             [Form('китай', Grams(Geox,NOUN,Sgtm,gent,inan,masc,sing))]),
#  Token(',', [856, 857), 'PUNCT'),
#  MorphToken('независимых',
#             [858, 869),
#             'RU',
#             [Form('независимый', Grams(ADJF,Qual,gent,plur)),
#              Form('независимый', Grams(ADJF,Qual,accs,anim,plur)),
#              Form('независимый', Grams(ADJF,Qual,loct,plur))]),
#  MorphToken('авторов',
#             [870, 877),
#             'RU',
#             [Form('автор', Grams(NOUN,anim,gent,masc,plur)),
#              Form('автор', Grams(NOUN,accs,anim,masc,plur))]),
#  MorphToken('из',
#             [878, 880),
#             'RU',
#             [Form('из', Grams(PREP)),
#              Form('иза', Grams(NOUN,Name,anim,femn,gent,plur)),
#              Form('иза', Grams(NOUN,Name,accs,anim,femn,plur))]),
#  MorphToken('Кубы',
#             [881, 885),
#             'RU',
#             [Form('куба', Grams(Geox,NOUN,Sgtm,femn,gent,inan,sing)),
#              Form('куб', Grams(NOUN,inan,masc,nomn,plur)),
#              Form('куб', Grams(NOUN,accs,inan,masc,plur))]),
#  Token(',', [885, 886), 'PUNCT'),
#  MorphToken('которые',
#             [887, 894),
#             'RU',
#             [Form('который', Grams(ADJF,Anph,Apro,Subx,nomn,plur)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,accs,inan,plur))]),
#  MorphToken('пишут',
#             [895, 900),
#             'RU',
#             [Form('писать', Grams(3per,VERB,impf,indc,plur,pres,tran))]),
#  MorphToken('для',
#             [901, 904),
#             'RU',
#             [Form('для', Grams(PREP)),
#              Form('длить', Grams(GRND,impf,pres,tran))]),
#  MorphToken('зарубежных',
#             [905, 915),
#             'RU',
#             [Form('зарубежный', Grams(ADJF,Qual,gent,plur)),
#              Form('зарубежный', Grams(ADJF,Qual,accs,anim,plur)),
#              Form('зарубежный', Grams(ADJF,Qual,loct,plur))]),
#  MorphToken('Интернет',
#             [916, 924),
#             'RU',
#             [Form('интернет', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('интернет', Grams(NOUN,accs,inan,masc,sing))]),
#  MorphToken('страниц',
#             [925, 932),
#             'RU',
#             [Form('страница', Grams(NOUN,femn,gent,inan,plur))]),
#  MorphToken('и',
#             [933, 934),
#             'RU',
#             [Form('и', Grams(CONJ)),
#              Form('и', Grams(INTJ)),
#              Form('и', Grams(PRCL)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,plur))]),
#  MorphToken('американского',
#             [935, 948),
#             'RU',
#             [Form('американский', Grams(ADJF,gent,neut,sing)),
#              Form('американский', Grams(ADJF,gent,masc,sing)),
#              Form('американский', Grams(ADJF,accs,anim,masc,sing))]),
#  MorphToken('видео',
#             [949, 954),
#             'RU',
#             [Form('видео', Grams(Fixd,NOUN,inan,neut,nomn,sing)),
#              Form('видео', Grams(Fixd,NOUN,accs,inan,neut,sing)),
#              Form('видео', Grams(Fixd,NOUN,inan,loct,neut,sing)),
#              Form('видео', Grams(Fixd,NOUN,gent,inan,neut,sing)),
#              Form('видео', Grams(Fixd,NOUN,datv,inan,neut,sing)),
#              Form('видео', Grams(Fixd,NOUN,ablt,inan,neut,sing)),
#              Form('видео', Grams(Fixd,NOUN,inan,neut,nomn,plur)),
#              Form('видео', Grams(Fixd,NOUN,gent,inan,neut,plur)),
#              Form('видео', Grams(Fixd,NOUN,datv,inan,neut,plur)),
#              Form('видео', Grams(Fixd,NOUN,accs,inan,neut,plur)),
#              Form('видео', Grams(Fixd,NOUN,ablt,inan,neut,plur)),
#              Form('видео', Grams(Fixd,NOUN,inan,loct,neut,plur))]),
#  Token('-', [954, 955), 'PUNCT'),
#  MorphToken('блоггера',
#             [955, 963),
#             'RU',
#             [Form('блоггер', Grams(NOUN,anim,gent,masc,sing)),
#              Form('блоггер', Grams(NOUN,accs,anim,masc,sing))]),
#  MorphToken('Джошуа',
#             [964, 970),
#             'RU',
#             [Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,anim,gent,masc,sing)),
#              Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,anim,masc,nomn,sing)),
#              Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,anim,datv,masc,sing)),
#              Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,accs,anim,masc,sing)),
#              Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,ablt,anim,masc,sing)),
#              Form('джошуа', Grams(Fixd,NOUN,Name,Sgtm,anim,loct,masc,sing))]),
#  MorphToken('Вольфа',
#             [971, 977),
#             'RU',
#             [Form('вольф', Grams(NOUN,Name,accs,anim,masc,sing)),
#              Form('вольф', Grams(NOUN,Name,anim,gent,masc,sing))]),
#  Token('(', [978, 979), 'PUNCT'),
#  Token('Joshua', [979, 985), 'LATIN'),
#  Token('Wolf', [986, 990), 'LATIN'),
#  Token(')', [990, 991), 'PUNCT'),
#  Token(',', [991, 992), 'PUNCT'),
#  MorphToken('который',
#             [993, 1000),
#             'RU',
#             [Form('который', Grams(ADJF,Anph,Apro,Subx,masc,nomn,sing)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,accs,inan,masc,sing))]),
#  MorphToken('отказался',
#             [1001, 1010),
#             'RU',
#             [Form('отказаться', Grams(VERB,indc,intr,masc,past,perf,sing))]),
#  MorphToken('передать',
#             [1011, 1019),
#             'RU',
#             [Form('передать', Grams(INFN,perf,tran))]),
#  MorphToken('материалы',
#             [1020, 1029),
#             'RU',
#             [Form('материал', Grams(NOUN,accs,inan,masc,plur)),
#              Form('материал', Grams(NOUN,inan,masc,nomn,plur))]),
#  MorphToken('большому',
#             [1030, 1038),
#             'RU',
#             [Form('большой', Grams(ADJF,Qual,datv,masc,sing)),
#              Form('большой', Grams(ADJF,Qual,datv,neut,sing))]),
#  MorphToken('жюри',
#             [1039, 1043),
#             'RU',
#             [Form('жюри', Grams(Fixd,NOUN,inan,neut,nomn,sing)),
#              Form('жюри', Grams(Fixd,NOUN,gent,inan,neut,sing)),
#              Form('жюри', Grams(Fixd,NOUN,datv,inan,neut,sing)),
#              Form('жюри', Grams(Fixd,NOUN,accs,inan,neut,sing)),
#              Form('жюри', Grams(Fixd,NOUN,ablt,inan,neut,sing)),
#              Form('жюри', Grams(Fixd,NOUN,inan,loct,neut,sing)),
#              Form('жюри', Grams(Fixd,NOUN,inan,neut,nomn,plur)),
#              Form('жюри', Grams(Fixd,NOUN,gent,inan,neut,plur)),
#              Form('жюри', Grams(Fixd,NOUN,datv,inan,neut,plur)),
#              Form('жюри', Grams(Fixd,NOUN,accs,inan,neut,plur)),
#              Form('жюри', Grams(Fixd,NOUN,ablt,inan,neut,plur)),
#              Form('жюри', Grams(Fixd,NOUN,inan,loct,neut,plur))]),
#  Token('.', [1043, 1044), 'PUNCT'),
#  Token('«', [1046, 1047), 'PUNCT'),
#  MorphToken('Мы',
#             [1047, 1049),
#             'RU',
#             [Form('мы', Grams(1per,NPRO,nomn,plur))]),
#  MorphToken('находимся',
#             [1050, 1059),
#             'RU',
#             [Form('находиться', Grams(1per,VERB,impf,indc,intr,plur,pres)),
#              Form('находиться', Grams(1per,VERB,futr,indc,intr,perf,plur)),
#              Form('находиться', Grams(VERB,impr,incl,intr,perf,sing))]),
#  MorphToken('на',
#             [1060, 1062),
#             'RU',
#             [Form('на', Grams(PREP)),
#              Form('на', Grams(PRCL)),
#              Form('на', Grams(INTJ))]),
#  MorphToken('критическом',
#             [1063, 1074),
#             'RU',
#             [Form('критический', Grams(ADJF,loct,neut,sing)),
#              Form('критический', Grams(ADJF,loct,masc,sing))]),
#  MorphToken('этапе',
#             [1075, 1080),
#             'RU',
#             [Form('этап', Grams(NOUN,inan,loct,masc,sing))]),
#  MorphToken('борьбы',
#             [1081, 1087),
#             'RU',
#             [Form('борьба', Grams(NOUN,Sgtm,femn,gent,inan,sing))]),
#  MorphToken('за', [1088, 1090), 'RU', [Form('за', Grams(PREP))]),
#  MorphToken('свободу',
#             [1091, 1098),
#             'RU',
#             [Form('свобода', Grams(NOUN,accs,femn,inan,sing))]),
#  MorphToken('прессы',
#             [1099, 1105),
#             'RU',
#             [Form('пресса', Grams(NOUN,femn,gent,inan,sing)),
#              Form('пресс', Grams(NOUN,inan,masc,nomn,plur)),
#              Form('пресс', Grams(NOUN,accs,inan,masc,plur)),
# ...
#  Token(',', [5668, 5669), 'PUNCT'),
#  MorphToken('отдавая',
#             [5670, 5677),
#             'RU',
#             [Form('отдавать', Grams(GRND,impf,pres,tran))]),
#  MorphToken('дань',
#             [5678, 5682),
#             'RU',
#             [Form('дань', Grams(NOUN,femn,inan,nomn,sing)),
#              Form('дань', Grams(NOUN,accs,femn,inan,sing)),
#              Form('даня', Grams(Infr,NOUN,Name,anim,masc,sing,voct)),
#              Form('даня', Grams(NOUN,Name,anim,gent,masc,plur)),
#              Form('даня', Grams(NOUN,Name,accs,anim,masc,plur))]),
#  MorphToken('погибшему',
#             [5683, 5692),
#             'RU',
#             [Form('погибший', Grams(ADJF,datv,masc,sing)),
#              Form('погибший', Grams(ADJF,datv,neut,sing)),
#              Form('погибнуть', Grams(PRTF,actv,datv,intr,masc,past,perf,sing)),
#              Form('погибнуть',
#                   Grams(PRTF,actv,datv,intr,neut,past,perf,sing))]),
#  MorphToken('Эдуард',
#             [5693, 5699),
#             'RU',
#             [Form('эдуард', Grams(NOUN,Name,anim,masc,nomn,sing)),
#              Form('эдуарда', Grams(NOUN,Name,anim,femn,gent,plur)),
#              Form('эдуарда', Grams(NOUN,Name,accs,anim,femn,plur))]),
#  MorphToken('Мишлен',
#             [5700, 5706),
#             'RU',
#             [Form('мишлена', Grams(NOUN,Name,anim,femn,gent,plur)),
#              Form('мишлена', Grams(NOUN,Name,accs,anim,femn,plur)),
#              Form('мишлена', Grams(Infr,NOUN,Name,anim,femn,sing,voct)),
#              Form('мишлен', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('мишлен', Grams(NOUN,accs,inan,masc,sing)),
#              Form('мишленный', Grams(ADJS,masc,sing)),
#              Form('мислить', Grams(PRTS,masc,past,perf,pssv,sing)),
#              Form('мишлёный', Grams(ADJS,Qual,masc,sing)),
#              Form('мишлёный', Grams(ADJS,masc,sing))]),
#  Token(',', [5706, 5707), 'PUNCT'),
#  MorphToken('одному',
#             [5708, 5714),
#             'RU',
#             [Form('один', Grams(ADJF,Apro,datv,masc,sing)),
#              Form('один', Grams(ADJF,Apro,datv,neut,sing))]),
#  MorphToken('из',
#             [5715, 5717),
#             'RU',
#             [Form('из', Grams(PREP)),
#              Form('иза', Grams(NOUN,Name,anim,femn,gent,plur)),
#              Form('иза', Grams(NOUN,Name,accs,anim,femn,plur))]),
#  MorphToken('президентов',
#             [5718, 5729),
#             'RU',
#             [Form('президент', Grams(NOUN,anim,gent,masc,plur)),
#              Form('президент', Grams(NOUN,accs,anim,masc,plur))]),
#  MorphToken('группы',
#             [5730, 5736),
#             'RU',
#             [Form('группа', Grams(NOUN,femn,gent,inan,sing)),
#              Form('группа', Grams(NOUN,femn,inan,nomn,plur)),
#              Form('группа', Grams(NOUN,accs,femn,inan,plur))]),
#  MorphToken('компаний',
#             [5737, 5745),
#             'RU',
#             [Form('компания', Grams(NOUN,femn,gent,inan,plur))]),
#  Token('Michelin', [5746, 5754), 'LATIN'),
#  Token(',', [5754, 5755), 'PUNCT'),
#  MorphToken('в',
#             [5756, 5757),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('составе',
#             [5758, 5765),
#             'RU',
#             [Form('состав', Grams(NOUN,inan,loct,masc,sing))]),
#  MorphToken('которой',
#             [5766, 5773),
#             'RU',
#             [Form('который', Grams(ADJF,Anph,Apro,Subx,femn,loct,sing)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,femn,gent,sing)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,datv,femn,sing)),
#              Form('который', Grams(ADJF,Anph,Apro,Subx,ablt,femn,sing))]),
#  MorphToken('и',
#             [5774, 5775),
#             'RU',
#             [Form('и', Grams(CONJ)),
#              Form('и', Grams(INTJ)),
#              Form('и', Grams(PRCL)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,sing)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,masc,nomn,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,gent,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,datv,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,accs,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,ablt,anim,masc,plur)),
#              Form('исполняющий', Grams(Abbr,Fixd,NOUN,anim,loct,masc,plur))]),
#  MorphToken('поставщик',
#             [5776, 5785),
#             'RU',
#             [Form('поставщик', Grams(NOUN,anim,masc,nomn,sing))]),
#  MorphToken('шин',
#             [5786, 5789),
#             'RU',
#             [Form('шина', Grams(NOUN,femn,gent,inan,plur))]),
#  MorphToken('для',
#             [5790, 5793),
#             'RU',
#             [Form('для', Grams(PREP)),
#              Form('длить', Grams(GRND,impf,pres,tran))]),
#  MorphToken('Формулы',
#             [5794, 5801),
#             'RU',
#             [Form('формула', Grams(NOUN,femn,gent,inan,sing)),
#              Form('формула', Grams(NOUN,femn,inan,nomn,plur)),
#              Form('формула', Grams(NOUN,accs,femn,inan,plur))]),
#  Token('-', [5801, 5802), 'PUNCT'),
#  Token('1', [5802, 5803), 'INT'),
#  Token(',', [5803, 5804), 'PUNCT'),
#  MorphToken('погибшему',
#             [5805, 5814),
#             'RU',
#             [Form('погибший', Grams(ADJF,datv,masc,sing)),
#              Form('погибший', Grams(ADJF,datv,neut,sing)),
#              Form('погибнуть', Grams(PRTF,actv,datv,intr,masc,past,perf,sing)),
#              Form('погибнуть',
#                   Grams(PRTF,actv,datv,intr,neut,past,perf,sing))]),
#  MorphToken('за', [5815, 5817), 'RU', [Form('за', Grams(PREP))]),
#  MorphToken('два',
#             [5818, 5821),
#             'RU',
#             [Form('два', Grams(NUMR,masc,nomn)),
#              Form('два', Grams(NUMR,accs,inan,masc)),
#              Form('два', Grams(NUMR,neut,nomn)),
#              Form('два', Grams(NUMR,accs,neut))]),
#  MorphToken('дня',
#             [5822, 5825),
#             'RU',
#             [Form('день', Grams(NOUN,gent,inan,masc,sing))]),
#  MorphToken('до', [5826, 5828), 'RU', [Form('до', Grams(PREP))]),
#  MorphToken('гонки',
#             [5829, 5834),
#             'RU',
#             [Form('гонка', Grams(NOUN,femn,gent,inan,sing)),
#              Form('гонка', Grams(NOUN,femn,inan,nomn,plur)),
#              Form('гонка', Grams(NOUN,accs,femn,inan,plur)),
#              Form('гонкий', Grams(ADJS,Qual,plur))]),
#  Token('.', [5834, 5835), 'PUNCT'),
#  MorphToken('Около',
#             [5836, 5841),
#             'RU',
#             [Form('около', Grams(PREP)), Form('около', Grams(ADVB))]),
#  Token('30', [5842, 5844), 'INT'),
#  MorphToken('рабочих',
#             [5845, 5852),
#             'RU',
#             [Form('рабочий', Grams(NOUN,anim,gent,masc,plur)),
#              Form('рабочий', Grams(NOUN,accs,anim,masc,plur)),
#              Form('рабочий', Grams(NOUN,anim,loct,masc,plur)),
#              Form('рабочий', Grams(ADJF,Qual,gent,plur)),
#              Form('рабочий', Grams(ADJF,Qual,accs,anim,plur)),
#              Form('рабочий', Grams(ADJF,Qual,loct,plur))]),
#  MorphToken('на',
#             [5853, 5855),
#             'RU',
#             [Form('на', Grams(PREP)),
#              Form('на', Grams(PRCL)),
#              Form('на', Grams(INTJ))]),
#  MorphToken('заводе',
#             [5856, 5862),
#             'RU',
#             [Form('завод', Grams(NOUN,inan,loct,masc,sing))]),
#  MorphToken('по', [5863, 5865), 'RU', [Form('по', Grams(PREP))]),
#  MorphToken('производству',
#             [5866, 5878),
#             'RU',
#             [Form('производство', Grams(NOUN,datv,inan,neut,sing))]),
#  MorphToken('ветрогенераторов',
#             [5879, 5895),
#             'RU',
#             [Form('ветрогенератор', Grams(NOUN,gent,inan,masc,plur))]),
#  Token('Vestas', [5896, 5902), 'LATIN'),
#  Token(',', [5902, 5903), 'PUNCT'),
#  MorphToken('расположенном',
#             [5904, 5917),
#             'RU',
#             [Form('расположить',
#                   Grams(PRTF,loct,masc,past,perf,pssv,sing,tran)),
#              Form('расположить',
#                   Grams(PRTF,loct,neut,past,perf,pssv,sing,tran))]),
#  MorphToken('в',
#             [5918, 5919),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('Ньюпорте',
#             [5920, 5928),
#             'RU',
#             [Form('ньюпорт', Grams(NOUN,inan,loct,masc,sing)),
#              Form('ньюпорт', Grams(NOUN,inan,loct,masc,sing)),
#              Form('ньюпорта', Grams(Geox,NOUN,Sgtm,datv,femn,inan,sing)),
#              Form('ньюпорта', Grams(Geox,NOUN,Sgtm,femn,inan,loct,sing)),
#              Form('ньюпорот', Grams(NOUN,anim,loct,masc,sing)),
#              Form('ньюпорот', Grams(NOUN,inan,loct,masc,sing)),
#              Form('ньюпорт', Grams(NOUN,Orgn,inan,loct,masc,sing))]),
#  Token(',', [5928, 5929), 'PUNCT'),
#  MorphToken('столицы',
#             [5930, 5937),
#             'RU',
#             [Form('столица', Grams(NOUN,femn,gent,inan,sing)),
#              Form('столица', Grams(NOUN,femn,inan,nomn,plur)),
#              Form('столица', Grams(NOUN,accs,femn,inan,plur))]),
#  MorphToken('Острова',
#             [5938, 5945),
#             'RU',
#             [Form('остров', Grams(NOUN,gent,inan,masc,sing)),
#              Form('остров', Grams(NOUN,inan,masc,nomn,plur)),
#              Form('остров', Grams(NOUN,accs,inan,masc,plur))]),
#  MorphToken('Уайт',
#             [5946, 5950),
#             'RU',
#             [Form('уайт', Grams(NOUN,Name,anim,masc,nomn,sing))]),
#  Token(',', [5950, 5951), 'PUNCT'),
#  MorphToken('Англия',
#             [5952, 5958),
#             'RU',
#             [Form('англия', Grams(Geox,NOUN,Sgtm,femn,inan,nomn,sing))]),
#  MorphToken('захватили',
#             [5959, 5968),
#             'RU',
#             [Form('захватить', Grams(VERB,indc,past,perf,plur,tran))]),
#  MorphToken('свой',
#             [5969, 5973),
#             'RU',
#             [Form('свой', Grams(ADJF,Anph,Apro,accs,inan,masc,sing)),
#              Form('свой', Grams(ADJF,Anph,Apro,masc,nomn,sing))]),
#  MorphToken('завод',
#             [5974, 5979),
#             'RU',
#             [Form('завод', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('завод', Grams(NOUN,accs,inan,masc,sing))]),
#  MorphToken('в',
#             [5980, 5981),
#             'RU',
#             [Form('в', Grams(PREP)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,sing)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,masc,nomn,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,gent,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,datv,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,accs,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,ablt,inan,masc,plur)),
#              Form('век', Grams(Abbr,Fixd,NOUN,inan,loct,masc,plur))]),
#  MorphToken('знак',
#             [5982, 5986),
#             'RU',
#             [Form('знак', Grams(NOUN,inan,masc,nomn,sing)),
#              Form('знак', Grams(NOUN,accs,inan,masc,sing))]),
#  MorphToken('протеста',
#             [5987, 5995),
#             'RU',
#             [Form('протест', Grams(NOUN,gent,inan,masc,sing))]),
#  MorphToken('против',
#             [5996, 6002),
#             'RU',
#             [Form('против', Grams(PREP)), Form('против', Grams(PRED,pres))]),
#  MorphToken('его',
#             [6003, 6006),
#             'RU',
#             [Form('он', Grams(3per,Anph,NPRO,accs,masc,sing)),
#              Form('оно', Grams(3per,Anph,NPRO,gent,neut,sing)),
#              Form('оно', Grams(3per,Anph,NPRO,accs,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,femn,gent,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,gent,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,nomn,plur)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,datv,plur)),
#              Form('он', Grams(3per,Anph,NPRO,gent,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,masc,nomn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,gent,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,datv,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,accs,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,ablt,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,loct,masc,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,femn,nomn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,datv,femn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,accs,femn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,ablt,femn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,femn,loct,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,neut,nomn,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,datv,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,accs,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,ablt,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,loct,neut,sing)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,gent,plur)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,accs,plur)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,ablt,plur)),
#              Form('его', Grams(ADJF,Anph,Apro,Fixd,loct,plur))]),
#  MorphToken('планируемого',
#             [6007, 6019),
#             'RU',
#             [Form('планировать',
#                   Grams(PRTF,gent,impf,neut,pres,pssv,sing,tran)),
#              Form('планировать',
#                   Grams(PRTF,gent,impf,masc,pres,pssv,sing,tran)),
#              Form('планировать',
#                   Grams(PRTF,accs,anim,impf,masc,pres,pssv,sing,tran))]),
#  MorphToken('закрытия',
#             [6020, 6028),
#             'RU',
#             [Form('закрытие', Grams(NOUN,gent,inan,neut,sing)),
#              Form('закрытие', Grams(NOUN,inan,neut,nomn,plur)),
#              Form('закрытие', Grams(NOUN,accs,inan,neut,plur))]),
#  Token('.', [6028, 6029), 'PUNCT'),
#  ...]

# %%
embeddings_filename = 'ruwikiruscorpora_upos_skipgram_300_2_2018.vec'

# %%
def load_embeddings(file_name):
    model = {}
    f = open(file_name, 'r')
    for line in f:
        splitline = line.split()
        word = splitline[0]
        embedding = np.array([float(val) for val in splitline[1:]])
        model[word] = embedding
    print ("Done",len(model)," words loaded!")
    return model

# %%
model = load_embeddings(embeddings_filename)
# Out:
# Done 384765  words loaded!

# %%
from yargy import Parser, rule, and_, or_
from yargy.interpretation import fact, attribute
from yargy.predicates import dictionary, gte, lte
from yargy.tokenizer import RULES

# %%
# Out:
# {'мотив', 'театром', 'высказаться', 'следствие', 'бег', 'пятнадцать', 'кёпке', 'террором', 'расчетов', '«реальным', 'отдельных', 'которых', 'кеннеди', 'кириллической', 'юрия', 'открыли', 'экономики', 'поступить', 'родины»', 'судьба', 'используя', 'чемпионате', 'петро-славянка', 'сейчас', 'выставлена', 'запрещает', 'times', '«бавария»', 'посольства', 'победитель', 'прессе»', 'подтвердил', 'ядерного', 'долгорукому', 'требования', 'результатах', 'евразийским', 'столкновениями', 'палестинское', 'продолжается»', 'дефицитом', 'повлиять', 'ближайшее', 'сети', 'смогли', 'инаркиев', 'телескоп', 'убеждена', 'полугодие', 'вайнрайх', 'сайтах', 'необходимым', 'требований', 'получат', 'отмечает', 'возвращают', 'постройкой', 'серьезных', '2602', 'африку', '«эта', 'теперь', '5000', 'оставаться', 'горацио', 'вынесем', 'эти', 'радиостанцию', 'задерживать', 'семья»', 'нидерланды', 'наконец', '«гол»', 'укладке', 'сообщить', 'технологии', 'минувшую', 'sex', 'показали', 'знаниями', 'ису', 'арабскими', 'ежегодно', 'работах', 'устья', 'считаем', 'нынешнего', 'указывают', 'севастьянов', 'лауреата', 'тянется', 'столичные', 'чудо', 'левон', 'петербурга', 'суть', 'ркк', 'рейсом', 'создали', 'reisman', 'страной', '«у', 'лиц', 'кристаллов', 'люблю', 'казалось', 'сосредотачивать', 'получилось', 'всё', '8', 'дверь', 'планируем', 'состоящая', 'содержать', 'вывести', 'браузера', 'трудности', 'приведет', 'просмотры', 'присоединении', 'прокуратуре', 'хранилось', '3512', '»', 'обретают', 'итоги', 'мир', 'неотъемлемой', 'chrome', 'однако', 'любителями', 'снов', 'оппонента', 'увязла', 'вызванного', 'официальная', 'мьянмы', '«кориера', 'соотношение', 'кремниевой', 'марин', 'внедрить', 'десятки', 'угрожал', 'размещённой', 'голос', 'лекарств', 'меджлиса', '«голоса', 'обитаемую', 'животных', 'африканских', 'покупки', 'забастовки', 'задерживали', 'настроены', 'уникальная', 'гор', 'главном', 'делегация', 'зависящих', 'коллективов', 'суперхайвей', 'маленьком', 'милиции', 'реформы', 'марок', 'неплохо', 'свалить', 'минкомсвязи', 'треки', 'приехавшие', 'страна', '1994', 'обнаружении', 'подала', 'реанимировать', 'детям', 'языка', 'существующие', 'наши', 'милиционеров', 'мигранты', 'освящение', 'лонгин', 'мальтийцы', 'бывшими', 'вынуждены', 'годы', 'потери', '2011', 'оглашены', 'третьих', 'стратегию', 'автономии', 'ультраправые»', 'обвинены', 'правда', 'замечания', 'очевидна', 'состоящую', 'теми', '«редкой', 'корне', 'существенную', 'сверхбольшие', 'этого', 'жилищный', 'оказалось', 'многое', 'идущий', 'невозможно', '150-летний', 'конвергентных', 'некляева', 'шаттлов', 'структуры', 'способствовали', 'высказался', 'к', 'china', 'держали', '«союз»', 'медицинской', 'вступить', 'помещений', 'договорённости', '«происхождение', 'судебные', 'выставлены', 'стампа"', 'неаполе', 'корабль', '16-й', 'страниц', 'чеченские', 'показавшиеся', 'представителями', 'начнем', 'объявила', 'необязательный', 'так', 'публиковать', 'балет', 'новый', '2—2', 'крупные', '48:55', 'вынесла', '0:1', 'маркос', 'подписали', 'скорее', 'трёхмерная', '«предусматривается', 'правило', 'разным', '4:3', 'спецслужбы', 'привезенныи', 'шестидневной', 'появится', 'проблемы»', 'постигла', 'смысл', 'шести', 'ведь', 'привычны', 'пострадают', 'скафандре', 'призёры', 'полного', 'корпорация', 'предприниматель', 'сфере', 'мир»', 'преемником', 'россии»', 'представляют', 'мануэль', 'погасили', 'реджепом', 'баков', 'очереди', 'заключённых', 'амбициозный', 'надежд', 'вид', 'наото', 'трагического', 'веществ', 'беспалов', 'совершают', 'общения', 'серверы', 'пребывание', 'седьмыми', 'супермаркетов', 'преследователей', 'настойчиво', 'счёте', 'предметов', 'законам', 'умерло', '"великая"', 'госдумы', 'представлены', 'пользователям', 'месте', 'утра', 'предоставляемые', 'библиографической', 'законы', 'doc»', 'краткие', 'показателем', 'победой', 'объёма', 'автомобилей', 'протеста', 'случаях', 'мертвой', '=', 'предъявляемым', 'новодевичьем', 'сократились', 'свинина', 'созданию', 'аль-хадж', 'бернс', 'потреблением', 'изменилось', 'народного',  ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-965ecaf2a3a9> in <module>()
# ----> 1 words.normalized()
#
# AttributeError: 'set' object has no attribute 'normalized'
